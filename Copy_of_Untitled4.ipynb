# %% [markdown]
# <a href="https://colab.research.google.com/github/Saurav8431/BODY-MASS-INDEX/blob/main/Copy_of_Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.tokenize import word_tokenize

# Download required resources (run once)
nltk.download('punkt')
nltk.download('punkt_tab')

text = "Tokenization is very easy to learn"
tokens = word_tokenize(text)

print(tokens)
import nltk

from nltk.tokenize import word_tokenize



# Download required resources (run once)

nltk.download('punkt')

nltk.download('punkt_tab')



text = "my name is saurav kumar"

tokens = word_tokenize(text)



print(tokens)
# Out:
# ['Tokenization', 'is', 'very', 'easy', 'to', 'learn']
# ['my', 'name', 'is', 'saurav', 'kumar']
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
