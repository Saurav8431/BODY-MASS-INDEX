# %% [markdown]
# <a href="https://colab.research.google.com/github/Saurav8431/BODY-MASS-INDEX/blob/main/named%20entity%20recognition(NER).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install spaCy and English model
# !pip install -q spacy
# !python -m spacy download en_core_web_sm -q

import spacy

# Load English model
nlp = spacy.load("en_core_web_sm")

text = "Apple is looking at buying U.K. startup for $1 billion"

# Process text
doc = nlp(text)

print("===== NER OUTPUT (spaCy) =====")
for ent in doc.ents:
    print(ent.text, "-", ent.label_)
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 13.3 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# ===== NER OUTPUT (spaCy) =====
# Apple - ORG
# U.K. - GPE
# $1 billion - MONEY
